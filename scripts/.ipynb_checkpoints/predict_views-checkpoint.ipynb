# %%
import pandas as pd
import numpy as np
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestRegressor

# %%
def mape(y, y_pred):
    return np.mean(np.absolute(np.divide(np.subtract(y, y_pred), y)))
mape([1, 1, 1], [1, 0, 0])
# Out:
# 0.66666666666666663

# %%
players = pd.read_csv("../data/player_data.csv")
train = pd.read_csv("../data/training_set.csv")
train_y = train.pop("Rounded Viewers")
test = pd.read_csv("../data/test_set.csv").drop("Total_Viewers", axis = 1)
game_data = pd.read_csv("../data/game_data.csv")

# %%
model = RandomForestRegressor(n_estimators = 100)
test
#model.fit(train, train_y)
# Out:
#       Season   Game_ID   Game_Date Away_Team Home_Team
# 0    2016-17  21600010  10/26/2016       DEN       NOP
# 1    2016-17  21600023  10/28/2016       HOU       DAL
# 2    2016-17  21600027  10/29/2016       BOS       CHA
# 3    2016-17  21600026  10/29/2016       ATL       PHI
# 4    2016-17  21600048   11/1/2016       LAL       IND
# 5    2016-17  21600053   11/1/2016       UTA       SAS
# 6    2016-17  21600050   11/1/2016       NYK       DET
# 7    2016-17  21600049   11/1/2016       SAC       MIA
# 8    2016-17  21600061   11/2/2016       CHI       BOS
# 9    2016-17  21600063   11/2/2016       POR       PHX
# 10   2016-17  21600069   11/3/2016       OKC       GSW
# 11   2016-17  21600066   11/3/2016       IND       MIL
# 12   2016-17  21600073   11/4/2016       NYK       CHI
# 13   2016-17  21600082   11/5/2016       DEN       DET
# 14   2016-17  21600096   11/7/2016       ORL       CHI
# 15   2016-17  21600093   11/7/2016       UTA       PHI
# 16   2016-17  21600112   11/9/2016       TOR       OKC
# 17   2016-17  21600113   11/9/2016       DET       PHX
# 18   2016-17  21600119  11/10/2016       GSW       DEN
# 19   2016-17  21600122  11/11/2016       CLE       WAS
# 20   2016-17  21600134  11/12/2016       SAS       HOU
# 21   2016-17  21600130  11/12/2016       BOS       IND
# 22   2016-17  21600133  11/12/2016       WAS       CHI
# 23   2016-17  21600132  11/12/2016       PHI       ATL
# 24   2016-17  21600138  11/12/2016       DET       DEN
# 25   2016-17  21600140  11/13/2016       CHA       CLE
# 26   2016-17  21600148  11/14/2016       BOS       NOP
# 27   2016-17  21600147  11/14/2016       OKC       DET
# 28   2016-17  21600149  11/14/2016       PHI       HOU
# 29   2016-17  21600160  11/16/2016       CLE       IND
# ..       ...       ...         ...       ...       ...
# 430  2017-18  21701094   3/25/2018       CLE       BKN
# 431  2017-18  21701100   3/25/2018       POR       OKC
# 432  2017-18  21701098   3/25/2018       NYK       WAS
# 433  2017-18  21701104   3/26/2018       LAL       DET
# 434  2017-18  21701123   3/28/2018       DAL       LAL
# 435  2017-18  21701117   3/28/2018       BKN       ORL
# 436  2017-18  21701128   3/29/2018       MIL       GSW
# 437  2017-18  21701125   3/29/2018       CHI       MIA
# 438  2017-18  21701127   3/29/2018       IND       SAC
# 439  2017-18  21701131   3/30/2018       NOP       CLE
# 440  2017-18  21701136   3/30/2018       MIL       LAL
# 441  2017-18  21701132   3/30/2018       PHX       HOU
# 442  2017-18  21701137   3/30/2018       LAC       POR
# 443  2017-18  21701135   3/30/2018       MEM       UTA
# 444  2017-18  21701155    4/1/2018       SAC       LAL
# 445  2017-18  21701144    4/1/2018       WAS       CHI
# 446  2017-18  21701147    4/1/2018       ORL       ATL
# 447  2017-18  21701162    4/3/2018       BOS       MIL
# 448  2017-18  21701164    4/3/2018       POR       DAL
# 449  2017-18  21701171    4/4/2018       BOS       TOR
# 450  2017-18  21701178    4/5/2018       BKN       MIL
# 451  2017-18  21701186    4/6/2018       MIA       NYK
# 452  2017-18  21701191    4/7/2018       DEN       LAC
# 453  2017-18  21701206    4/9/2018       OKC       MIA
# 454  2017-18  21701205    4/9/2018       CHI       BKN
# 455  2017-18  21701213   4/10/2018       CHA       IND
# 456  2017-18  21701229   4/11/2018       UTA       POR
# 457  2017-18  21701230   4/11/2018       HOU       SAC
# 458  2017-18  21701222   4/11/2018       WAS       ORL
# 459  2017-18  21701224   4/11/2018       DET       CHI
#
# [460 rows x 5 columns]
